# %%
import pandas as pd

data = {
    "house_age": [10,20,5,30,15],
    "location_risk": [0.2,0.8,0.1,0.9,0.4],
    "roof_type": [1,2,1,3,2],
    "past_claims": [0,2,0,3,1],
    "property_value": [500000,300000,700000,200000,400000],
    "claim_occurred": [0,1,0,1,0]
}

df = pd.DataFrame(data)
df.to_csv(r"C:\Users\DELL\Desktop\sample_project\DSMLHINPROJECT\insurance-risk-ml\data\sample_data.csv", index=False)

print("✅ CSV created successfully")
# Out:
# ✅ CSV created successfully
